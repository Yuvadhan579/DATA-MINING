# %%
#APRIORI - FOOD TRANSACTION
import numpy as np
import pandas as pd
from  mlxtend.preprocessing import TransactionEncoder
from mlxtend .frequent_patterns import apriori, association_rules
df=pd.read_csv("Downloads/online_food_transactions.csv")
df
# Out:
#     TID                                      Items
# 0     1              Idli,Ice Cream,Samosa,Paratha
# 1     2         Pizza,Fries,Coke,Tea,Juice,Biryani
# 2     3               Burger,Biryani,Samosa,Paneer
# 3     4       Pepsi,Tea,Sandwich,Pizza,Dosa,Burger
# 4     5                          Pepsi,Coffee,Coke
# 5     6   Pasta,Salad,Coffee,Paratha,Juice,Biryani
# 6     7               Biryani,Noodles,Pizza,Paneer
# 7     8              Sandwich,Biryani,Coffee,Juice
# 8     9                   Salad,Biryani,Pepsi,Idli
# 9    10                         Coke,Fries,Biryani
# 10   11                         Pizza,Pasta,Paneer
# 11   12            Pizza,Pasta,Biryani,Paneer,Coke
# 12   13               Idli,Ice Cream,Noodles,Pizza
# 13   14                  Tea,Idli,Coffee,Coke,Cake
# 14   15  Biryani,Coke,Coffee,Paratha,Samosa,Burger
# 15   16                      Pasta,Juice,Dosa,Idli
# 16   17                 Salad,Fries,Paneer,Noodles
# 17   18    Paratha,Juice,Samosa,Tea,Sandwich,Pizza
# 18   19                       Cake,Pizza,Juice,Tea
# 19   20                        Coffee,Pizza,Paneer
# 20   21          Salad,Fries,Samosa,Cake,Pasta,Tea
# 21   22                            Idli,Fries,Cake
# 22   23                        Pizza,Pepsi,Biryani
# 23   24                  Coffee,Tea,Ice Cream,Idli
# 24   25    Juice,Coke,Noodles,Idli,Sandwich,Coffee
# 25   26                           Pasta,Juice,Cake
# 26   27            Paneer,Idli,Noodles,Pizza,Juice
# 27   28              Coke,Paneer,Salad,Burger,Dosa
# 28   29       Cake,Ice Cream,Paratha,Idli,Sandwich
# 29   30                          Samosa,Coke,Salad
# 30   31  Sandwich,Coke,Tea,Ice Cream,Biryani,Fries
# 31   32           Cake,Paneer,Noodles,Coke,Biryani
# 32   33  Pizza,Dosa,Samosa,Paratha,Coffee,Sandwich
# 33   34     Paratha,Coffee,Pizza,Fries,Pasta,Salad
# 34   35     Paneer,Paratha,Samosa,Salad,Cake,Fries
# 35   36            Fries,Idli,Biryani,Pizza,Paneer
# 36   37                         Pasta,Salad,Paneer
# 37   38                      Cake,Coke,Pasta,Pepsi
# 38   39                Paneer,Biryani,Noodles,Dosa
# 39   40           Dosa,Paneer,Samosa,Salad,Paratha
# 40   41                Coffee,Coke,Tea,Salad,Pizza
# 41   42                       Biryani,Pepsi,Paneer
# 42   43                  Dosa,Juice,Burger,Paratha
# 43   44                       Dosa,Samosa,Sandwich
# 44   45        Paneer,Biryani,Tea,Dosa,Juice,Pizza
# 45   46       Pepsi,Noodles,Sandwich,Samosa,Burger
# 46   47                 Sandwich,Coffee,Dosa,Pasta
# 47   48                            Pizza,Tea,Juice
# 48   49            Sandwich,Coke,Tea,Paneer,Coffee
# 49   50                   Cake,Biryani,Pepsi,Pizza

# %%
transactions=df['Items'].apply(lambda x:x.split(",")).tolist()
print(transactions)
# Out:
# [['Idli', 'Ice Cream', 'Samosa', 'Paratha'], ['Pizza', 'Fries', 'Coke', 'Tea', 'Juice', 'Biryani'], ['Burger', 'Biryani', 'Samosa', 'Paneer'], ['Pepsi', 'Tea', 'Sandwich', 'Pizza', 'Dosa', 'Burger'], ['Pepsi', 'Coffee', 'Coke'], ['Pasta', 'Salad', 'Coffee', 'Paratha', 'Juice', 'Biryani'], ['Biryani', 'Noodles', 'Pizza', 'Paneer'], ['Sandwich', 'Biryani', 'Coffee', 'Juice'], ['Salad', 'Biryani', 'Pepsi', 'Idli'], ['Coke', 'Fries', 'Biryani'], ['Pizza', 'Pasta', 'Paneer'], ['Pizza', 'Pasta', 'Biryani', 'Paneer', 'Coke'], ['Idli', 'Ice Cream', 'Noodles', 'Pizza'], ['Tea', 'Idli', 'Coffee', 'Coke', 'Cake'], ['Biryani', 'Coke', 'Coffee', 'Paratha', 'Samosa', 'Burger'], ['Pasta', 'Juice', 'Dosa', 'Idli'], ['Salad', 'Fries', 'Paneer', 'Noodles'], ['Paratha', 'Juice', 'Samosa', 'Tea', 'Sandwich', 'Pizza'], ['Cake', 'Pizza', 'Juice', 'Tea'], ['Coffee', 'Pizza', 'Paneer'], ['Salad', 'Fries', 'Samosa', 'Cake', 'Pasta', 'Tea'], ['Idli', 'Fries', 'Cake'], ['Pizza', 'Pepsi', 'Biryani'], ['Coffee', 'Tea', 'Ice Cream', 'Idli'], ['Juice', 'Coke', 'Noodles', 'Idli', 'Sandwich', 'Coffee'], ['Pasta', 'Juice', 'Cake'], ['Paneer', 'Idli', 'Noodles', 'Pizza', 'Juice'], ['Coke', 'Paneer', 'Salad', 'Burger', 'Dosa'], ['Cake', 'Ice Cream', 'Paratha', 'Idli', 'Sandwich'], ['Samosa', 'Coke', 'Salad'], ['Sandwich', 'Coke', 'Tea', 'Ice Cream', 'Biryani', 'Fries'], ['Cake', 'Paneer', 'Noodles', 'Coke', 'Biryani'], ['Pizza', 'Dosa', 'Samosa', 'Paratha', 'Coffee', 'Sandwich'], ['Paratha', 'Coffee', 'Pizza', 'Fries', 'Pasta', 'Salad'], ['Paneer', 'Paratha', 'Samosa', 'Salad', 'Cake', 'Fries'], ['Fries', 'Idli', 'Biryani', 'Pizza', 'Paneer'], ['Pasta', 'Salad', 'Paneer'], ['Cake', 'Coke', 'Pasta', 'Pepsi'], ['Paneer', 'Biryani', 'Noodles', 'Dosa'], ['Dosa', 'Paneer', 'Samosa', 'Salad', 'Paratha'], ['Coffee', 'Coke', 'Tea', 'Salad', 'Pizza'], ['Biryani', 'Pepsi', 'Paneer'], ['Dosa', 'Juice', 'Burger', 'Paratha'], ['Dosa', 'Samosa', 'Sandwich'], ['Paneer', 'Biryani', 'Tea', 'Dosa', 'Juice', 'Pizza'], ['Pepsi', 'Noodles', 'Sandwich', 'Samosa', 'Burger'], ['Sandwich', 'Coffee', 'Dosa', 'Pasta'], ['Pizza', 'Tea', 'Juice'], ['Sandwich', 'Coke', 'Tea', 'Paneer', 'Coffee'], ['Cake', 'Biryani', 'Pepsi', 'Pizza']]

# %%
#Step 2: One hot coding to transform data into true/false format
te=TransactionEncoder()
te_array=te.fit(transactions).transform(transactions)
df_encoded=pd.DataFrame(te_array,columns=te.columns_)

# %%
#Step 3:Apriori algorithm
frequen_itemsets=apriori(df_encoded,min_support=0.01,use_colnames=True)
print("Total Frequent Itemsets:",frequen_itemsets.shape[0])
# Out:
# Total Frequent Itemsets: 881

# %%
#Step 4: Visualize most popular items
import matplotlib.pyplot as plt
all_items = [item for sublist in transactions for item in sublist]
top_items=pd.Series(all_items).value_counts()
top_items.plot(kind='bar',title='Top food items purchased')
plt.xlabel('food items')
plt.ylabel('Frequency')
plt.show()

# %%
#Step 5: Association generate association rule
rules=association_rules(frequen_itemsets,metric='confidence',min_threshold=0.1)
rules=rules[rules['antecedents'].apply(lambda x:len(x)>=1) & rules['consequents'].apply(lambda x:len(x)>=1)]
print("Association rules:",rules.shape[0])
rules[['antecedents','consequents','support','confidence','lift']].head(5)
# Out:
# Association rules: 7097
#   antecedents consequents  support  confidence      lift
# 0    (Burger)   (Biryani)     0.04    0.333333  0.980392
# 1   (Biryani)    (Burger)     0.04    0.117647  0.980392
# 2      (Cake)   (Biryani)     0.04    0.200000  0.588235
# 3   (Biryani)      (Cake)     0.04    0.117647  0.588235
# 4    (Coffee)   (Biryani)     0.06    0.230769  0.678733
